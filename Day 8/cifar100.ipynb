# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.utils import to_categorical

# %%
(train_images, train_labels), (test_images, test_labels) = keras.datasets.cifar100.load_data()

# %%
train_images.shape
# Out:
# (50000, 32, 32, 3)

# %%
test_images.shape
# Out:
# (10000, 32, 32, 3)

# %%
train_labels.shape
# Out:
# (50000, 1)

# %%
test_labels.shape
# Out:
# (10000, 1)

# %%
train_images = train_images.astype('float32') / 255.0
test_images = test_images.astype('float32') / 255.0

# %%
def rgb_to_grayscale(images):
    grayscale = tf.image.rgb_to_grayscale(images)
    return grayscale
train_images_gray = rgb_to_grayscale(train_images)
test_images_gray = rgb_to_grayscale(test_images)
train_images_gray = train_images_gray.numpy()
test_images_gray = test_images_gray.numpy()

# %%
plt.figure()
plt.imshow(train_images_gray[0],cmap = plt.cm.gray)
plt.colorbar()
plt.grid(False)
plt.show()

# %%
train_labels_one_hot = to_categorical(train_labels,num_classes = 100)

# %%
test_labels_one_hot = to_categorical(test_labels,num_classes = 100)

# %%
ann_model = keras.Sequential([
    keras.Input(shape=(32, 32, 1)),
    keras.layers.Flatten(),
    keras.layers.Dense(512,activation='relu'),
    keras.layers.Dense(256,activation='relu'),
    keras.layers.Dense(100,activation='softmax')
])
ann_model.compile(optimizer = 'adam',
                  loss = 'categorical_crossentropy',
                  metrics = ['accuracy'])
ann_model.summary()
# Out:
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_13 (Flatten)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_37 (Dense)                │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_38 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_39 (Dense)                │ (None, 100)            │        25,700 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 681,828 (2.60 MB)
#  Trainable params: 681,828 (2.60 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
ann_model.fit(train_images_gray,
              train_labels_one_hot,
              epochs = 100,
              batch_size = 50,
              validation_data = (test_images_gray,test_labels_one_hot))
# Out:
# Epoch 1/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.0468 - loss: 4.3475 - val_accuracy: 0.0744 - val_loss: 4.1820
# Epoch 2/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.0839 - loss: 4.1022 - val_accuracy: 0.0956 - val_loss: 4.0616
# Epoch 3/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.1022 - loss: 3.9902 - val_accuracy: 0.1116 - val_loss: 3.9763
# Epoch 4/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.1185 - loss: 3.9027 - val_accuracy: 0.1190 - val_loss: 3.9467
# Epoch 5/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.1295 - loss: 3.8398 - val_accuracy: 0.1187 - val_loss: 3.9327
# Epoch 6/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.1361 - loss: 3.7852 - val_accuracy: 0.1350 - val_loss: 3.8652
# Epoch 7/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.1445 - loss: 3.7330 - val_accuracy: 0.1377 - val_loss: 3.8436
# Epoch 8/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.1516 - loss: 3.6916 - val_accuracy: 0.1454 - val_loss: 3.8176
# Epoch 9/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.1570 - loss: 3.6559 - val_accuracy: 0.1402 - val_loss: 3.8292
# Epoch 10/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.1634 - loss: 3.6143 - val_accuracy: 0.1487 - val_loss: 3.8213
# Epoch 11/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.1693 - loss: 3.5841 - val_accuracy: 0.1458 - val_loss: 3.8207
# Epoch 12/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.1725 - loss: 3.5539 - val_accuracy: 0.1416 - val_loss: 3.8477
# Epoch 13/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.1768 - loss: 3.5221 - val_accuracy: 0.1476 - val_loss: 3.8248
# Epoch 14/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.1822 - loss: 3.4969 - val_accuracy: 0.1475 - val_loss: 3.8369
# Epoch 15/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.1869 - loss: 3.4682 - val_accuracy: 0.1583 - val_loss: 3.8159
# Epoch 16/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.1922 - loss: 3.4402 - val_accuracy: 0.1482 - val_loss: 3.8367
# Epoch 17/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.1955 - loss: 3.4114 - val_accuracy: 0.1523 - val_loss: 3.8371
# Epoch 18/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.2027 - loss: 3.3918 - val_accuracy: 0.1511 - val_loss: 3.8340
# Epoch 19/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.2051 - loss: 3.3694 - val_accuracy: 0.1558 - val_loss: 3.8316
# Epoch 20/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.2096 - loss: 3.3402 - val_accuracy: 0.1509 - val_loss: 3.8855
# Epoch 21/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.2132 - loss: 3.3200 - val_accuracy: 0.1527 - val_loss: 3.8945
# Epoch 22/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.2160 - loss: 3.3052 - val_accuracy: 0.1492 - val_loss: 3.9162
# Epoch 23/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.2215 - loss: 3.2779 - val_accuracy: 0.1491 - val_loss: 3.9626
# Epoch 24/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.2261 - loss: 3.2515 - val_accuracy: 0.1541 - val_loss: 3.9304
# Epoch 25/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.2269 - loss: 3.2413 - val_accuracy: 0.1518 - val_loss: 3.9586
# Epoch 26/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.2327 - loss: 3.2176 - val_accuracy: 0.1535 - val_loss: 3.9625
# Epoch 27/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.2353 - loss: 3.2025 - val_accuracy: 0.1432 - val_loss: 4.0225
# Epoch 28/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.2375 - loss: 3.1834 - val_accuracy: 0.1493 - val_loss: 4.0258
# Epoch 29/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.2406 - loss: 3.1624 - val_accuracy: 0.1415 - val_loss: 4.0797
# Epoch 30/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.2433 - loss: 3.1466 - val_accuracy: 0.1480 - val_loss: 4.0496
# Epoch 31/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.2470 - loss: 3.1311 - val_accuracy: 0.1480 - val_loss: 4.0765
# Epoch 32/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.2516 - loss: 3.1113 - val_accuracy: 0.1495 - val_loss: 4.0747
# Epoch 33/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.2542 - loss: 3.0966 - val_accuracy: 0.1494 - val_loss: 4.1432
# Epoch 34/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.2587 - loss: 3.0834 - val_accuracy: 0.1519 - val_loss: 4.1454
# Epoch 35/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.2601 - loss: 3.0685 - val_accuracy: 0.1526 - val_loss: 4.1410
# Epoch 36/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.2620 - loss: 3.0537 - val_accuracy: 0.1459 - val_loss: 4.1617
# Epoch 37/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.2655 - loss: 3.0421 - val_accuracy: 0.1513 - val_loss: 4.1635
# Epoch 38/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.2690 - loss: 3.0280 - val_accuracy: 0.1495 - val_loss: 4.2541
# Epoch 39/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.2688 - loss: 3.0139 - val_accuracy: 0.1460 - val_loss: 4.2482
# Epoch 40/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.2713 - loss: 3.0020 - val_accuracy: 0.1481 - val_loss: 4.2773
# Epoch 41/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.2755 - loss: 2.9861 - val_accuracy: 0.1441 - val_loss: 4.2860
# Epoch 42/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.2774 - loss: 2.9725 - val_accuracy: 0.1516 - val_loss: 4.3050
# Epoch 43/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.2804 - loss: 2.9603 - val_accuracy: 0.1465 - val_loss: 4.3160
# Epoch 44/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.2822 - loss: 2.9509 - val_accuracy: 0.1509 - val_loss: 4.3842
# Epoch 45/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.2863 - loss: 2.9368 - val_accuracy: 0.1523 - val_loss: 4.3850
# Epoch 46/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.2894 - loss: 2.9262 - val_accuracy: 0.1440 - val_loss: 4.4600
# Epoch 47/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.2906 - loss: 2.9143 - val_accuracy: 0.1497 - val_loss: 4.4580
# Epoch 48/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.2912 - loss: 2.9058 - val_accuracy: 0.1502 - val_loss: 4.4453
# Epoch 49/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.
100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.3452 - loss: 2.6350 - val_accuracy: 0.1382 - val_loss: 5.3202
# Epoch 83/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.3495 - loss: 2.6157 - val_accuracy: 0.1365 - val_loss: 5.4472
# Epoch 84/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.3502 - loss: 2.6157 - val_accuracy: 0.1402 - val_loss: 5.4456
# Epoch 85/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.3500 - loss: 2.6142 - val_accuracy: 0.1350 - val_loss: 5.4024
# Epoch 86/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.3522 - loss: 2.6086 - val_accuracy: 0.1431 - val_loss: 5.3890
# Epoch 87/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.3541 - loss: 2.5957 - val_accuracy: 0.1293 - val_loss: 5.6792
# Epoch 88/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.3547 - loss: 2.5909 - val_accuracy: 0.1407 - val_loss: 5.4206
# Epoch 89/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.3589 - loss: 2.5802 - val_accuracy: 0.1330 - val_loss: 5.5845
# Epoch 90/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.3599 - loss: 2.5771 - val_accuracy: 0.1380 - val_loss: 5.4951
# Epoch 91/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.3615 - loss: 2.5723 - val_accuracy: 0.1379 - val_loss: 5.6604
# Epoch 92/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.3594 - loss: 2.5685 - val_accuracy: 0.1407 - val_loss: 5.6418
# Epoch 93/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.3641 - loss: 2.5640 - val_accuracy: 0.1399 - val_loss: 5.5276
# Epoch 94/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.3618 - loss: 2.5605 - val_accuracy: 0.1401 - val_loss: 5.5961
# Epoch 95/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.3671 - loss: 2.5458 - val_accuracy: 0.1354 - val_loss: 5.6119
# Epoch 96/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.3636 - loss: 2.5508 - val_accuracy: 0.1394 - val_loss: 5.6194
# Epoch 97/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.3691 - loss: 2.5393 - val_accuracy: 0.1399 - val_loss: 5.6406
# Epoch 98/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.3677 - loss: 2.5429 - val_accuracy: 0.1370 - val_loss: 5.7080
# Epoch 99/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.3674 - loss: 2.5329 - val_accuracy: 0.1397 - val_loss: 5.8892
# Epoch 100/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.3704 - loss: 2.5245 - val_accuracy: 0.1382 - val_loss: 5.8085

# %%
basic_cnn = keras.Sequential([
    keras.Input(shape=(32,32,1)),
    keras.layers.Conv2D(32, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(64, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(512, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(100, activation='softmax')
])
basic_cnn.compile(optimizer = 'adam',
                  loss = 'categorical_crossentropy',
                  metrics = ['accuracy'])
ann_model.summary()
# Out:
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_13 (Flatten)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_37 (Dense)                │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_38 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_39 (Dense)                │ (None, 100)            │        25,700 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,045,486 (7.80 MB)
#  Trainable params: 681,828 (2.60 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,363,658 (5.20 MB)

# %%
basic_cnn.fit(
    train_images_gray,
    train_labels_one_hot,
    epochs = 100,
    batch_size = 50,
    validation_data = (test_images_gray,test_labels_one_hot)
)
# Out:
# Epoch 1/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - accuracy: 0.1047 - loss: 3.9779 - val_accuracy: 0.1737 - val_loss: 3.5202
# Epoch 2/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.2247 - loss: 3.2461 - val_accuracy: 0.2448 - val_loss: 3.1251
# Epoch 3/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.2964 - loss: 2.8631 - val_accuracy: 0.2848 - val_loss: 2.9442
# Epoch 4/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.3511 - loss: 2.5828 - val_accuracy: 0.3088 - val_loss: 2.8573
# Epoch 5/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.4008 - loss: 2.3286 - val_accuracy: 0.3118 - val_loss: 2.8247
# Epoch 6/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.4566 - loss: 2.0855 - val_accuracy: 0.3233 - val_loss: 2.8441
# Epoch 7/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.5065 - loss: 1.8567 - val_accuracy: 0.3239 - val_loss: 2.8917
# Epoch 8/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.5571 - loss: 1.6353 - val_accuracy: 0.3220 - val_loss: 3.0322
# Epoch 9/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.6132 - loss: 1.4077 - val_accuracy: 0.3167 - val_loss: 3.2400
# Epoch 10/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.6654 - loss: 1.1950 - val_accuracy: 0.3119 - val_loss: 3.5211
# Epoch 11/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.7156 - loss: 0.9864 - val_accuracy: 0.3117 - val_loss: 3.7780
# Epoch 12/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.7626 - loss: 0.8069 - val_accuracy: 0.3037 - val_loss: 4.1826
# Epoch 13/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.8013 - loss: 0.6585 - val_accuracy: 0.2986 - val_loss: 4.5787
# Epoch 14/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.8398 - loss: 0.5295 - val_accuracy: 0.2973 - val_loss: 4.9467
# Epoch 15/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.8652 - loss: 0.4368 - val_accuracy: 0.3084 - val_loss: 5.4150
# Epoch 16/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.8830 - loss: 0.3692 - val_accuracy: 0.2918 - val_loss: 5.7903
# Epoch 17/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.8990 - loss: 0.3195 - val_accuracy: 0.2871 - val_loss: 6.4078
# Epoch 18/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9058 - loss: 0.2939 - val_accuracy: 0.2916 - val_loss: 6.6267
# Epoch 19/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9186 - loss: 0.2535 - val_accuracy: 0.2875 - val_loss: 7.0222
# Epoch 20/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9269 - loss: 0.2303 - val_accuracy: 0.2899 - val_loss: 7.5312
# Epoch 21/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9205 - loss: 0.2417 - val_accuracy: 0.2819 - val_loss: 7.4266
# Epoch 22/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9292 - loss: 0.2243 - val_accuracy: 0.2832 - val_loss: 7.6651
# Epoch 23/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9337 - loss: 0.2052 - val_accuracy: 0.2860 - val_loss: 8.0276
# Epoch 24/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9383 - loss: 0.1929 - val_accuracy: 0.2893 - val_loss: 8.2085
# Epoch 25/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9362 - loss: 0.1983 - val_accuracy: 0.2831 - val_loss: 8.2722
# Epoch 26/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9405 - loss: 0.1814 - val_accuracy: 0.2896 - val_loss: 8.7539
# Epoch 27/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9429 - loss: 0.1820 - val_accuracy: 0.2824 - val_loss: 8.6722
# Epoch 28/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9418 - loss: 0.1838 - val_accuracy: 0.2841 - val_loss: 8.9970
# Epoch 29/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9433 - loss: 0.1759 - val_accuracy: 0.2869 - val_loss: 9.1660
# Epoch 30/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9525 - loss: 0.1526 - val_accuracy: 0.2873 - val_loss: 9.2942
# Epoch 31/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9470 - loss: 0.1688 - val_accuracy: 0.2795 - val_loss: 9.4370
# Epoch 32/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9487 - loss: 0.1642 - val_accuracy: 0.2897 - val_loss: 9.6342
# Epoch 33/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9485 - loss: 0.1651 - val_accuracy: 0.2827 - val_loss: 9.8205
# Epoch 34/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9500 - loss: 0.1593 - val_accuracy: 0.2812 - val_loss: 10.0028
# Epoch 35/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9592 - loss: 0.1303 - val_accuracy: 0.2808 - val_loss: 10.3308
# Epoch 36/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9494 - loss: 0.1665 - val_accuracy: 0.2765 - val_loss: 10.3074
# Epoch 37/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9527 - loss: 0.1521 - val_accuracy: 0.2824 - val_loss: 10.5125
# Epoch 38/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9546 - loss: 0.1526 - val_accuracy: 0.2861 - val_loss: 10.4958
# Epoch 39/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9546 - loss: 0.1469 - val_accuracy: 0.2825 - val_loss: 10.4708
# Epoch 40/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.
100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 16s 16ms/step - accuracy: 0.9677 - loss: 0.1138 - val_accuracy: 0.2751 - val_loss: 14.8159
# Epoch 74/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9700 - loss: 0.1114 - val_accuracy: 0.2752 - val_loss: 14.6385
# Epoch 75/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 16s 16ms/step - accuracy: 0.9710 - loss: 0.1073 - val_accuracy: 0.2762 - val_loss: 14.7919
# Epoch 76/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 16s 16ms/step - accuracy: 0.9695 - loss: 0.1076 - val_accuracy: 0.2668 - val_loss: 15.2482
# Epoch 77/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 16s 16ms/step - accuracy: 0.9696 - loss: 0.1129 - val_accuracy: 0.2741 - val_loss: 15.1378
# Epoch 78/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 16s 16ms/step - accuracy: 0.9710 - loss: 0.1094 - val_accuracy: 0.2814 - val_loss: 15.0394
# Epoch 79/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 16s 16ms/step - accuracy: 0.9756 - loss: 0.0847 - val_accuracy: 0.2746 - val_loss: 15.1506
# Epoch 80/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 16s 16ms/step - accuracy: 0.9701 - loss: 0.1104 - val_accuracy: 0.2741 - val_loss: 15.2007
# Epoch 81/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9689 - loss: 0.1149 - val_accuracy: 0.2703 - val_loss: 15.3481
# Epoch 82/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9730 - loss: 0.0956 - val_accuracy: 0.2725 - val_loss: 15.4410
# Epoch 83/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 16s 16ms/step - accuracy: 0.9734 - loss: 0.1021 - val_accuracy: 0.2780 - val_loss: 15.4425
# Epoch 84/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9702 - loss: 0.1069 - val_accuracy: 0.2730 - val_loss: 15.6640
# Epoch 85/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 16s 16ms/step - accuracy: 0.9735 - loss: 0.0966 - val_accuracy: 0.2741 - val_loss: 15.6519
# Epoch 86/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 13s 13ms/step - accuracy: 0.9709 - loss: 0.1071 - val_accuracy: 0.2707 - val_loss: 15.4570
# Epoch 87/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 13s 13ms/step - accuracy: 0.9761 - loss: 0.0886 - val_accuracy: 0.2714 - val_loss: 15.6347
# Epoch 88/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 12s 12ms/step - accuracy: 0.9718 - loss: 0.1084 - val_accuracy: 0.2702 - val_loss: 16.0985
# Epoch 89/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 12s 12ms/step - accuracy: 0.9724 - loss: 0.1075 - val_accuracy: 0.2726 - val_loss: 16.1368
# Epoch 90/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 12s 12ms/step - accuracy: 0.9732 - loss: 0.0999 - val_accuracy: 0.2721 - val_loss: 16.2612
# Epoch 91/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 12s 12ms/step - accuracy: 0.9734 - loss: 0.1024 - val_accuracy: 0.2720 - val_loss: 16.2055
# Epoch 92/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 12s 12ms/step - accuracy: 0.9753 - loss: 0.0901 - val_accuracy: 0.2731 - val_loss: 16.4752
# Epoch 93/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 12s 12ms/step - accuracy: 0.9721 - loss: 0.1079 - val_accuracy: 0.2737 - val_loss: 16.3523
# Epoch 94/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 13s 13ms/step - accuracy: 0.9767 - loss: 0.0859 - val_accuracy: 0.2679 - val_loss: 16.8314
# Epoch 95/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 13s 13ms/step - accuracy: 0.9739 - loss: 0.1072 - val_accuracy: 0.2741 - val_loss: 16.4095
# Epoch 96/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 13s 13ms/step - accuracy: 0.9754 - loss: 0.0979 - val_accuracy: 0.2663 - val_loss: 16.5554
# Epoch 97/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 12s 12ms/step - accuracy: 0.9734 - loss: 0.1068 - val_accuracy: 0.2669 - val_loss: 16.5527
# Epoch 98/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 12s 12ms/step - accuracy: 0.9742 - loss: 0.1010 - val_accuracy: 0.2716 - val_loss: 17.1180
# Epoch 99/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 13s 13ms/step - accuracy: 0.9766 - loss: 0.0895 - val_accuracy: 0.2713 - val_loss: 17.0301
# Epoch 100/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 13s 13ms/step - accuracy: 0.9736 - loss: 0.1011 - val_accuracy: 0.2693 - val_loss: 17.1002

# %%
np.argmax(ann_model.predict(np.expand_dims(train_images_gray[0],axis=0)))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 19

# %%
np.argmax(basic_cnn.predict(np.expand_dims(train_images_gray[0],axis=0)))
# Out:
# WARNING:tensorflow:5 out of the last 944 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001A244965300> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 19

# %%
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import ReduceLROnPlateau

# 1. Define the data augmentation block
data_augmentation = keras.Sequential([
    keras.layers.RandomFlip("horizontal"),
    keras.layers.RandomRotation(0.1),
    keras.layers.RandomZoom(0.1),
])

# 2. Define the improved model
deeper_cnn = keras.Sequential([
    keras.Input(shape=(32, 32, 1)),
    
    # Augmentation layer
    data_augmentation,

    # Convolutional blocks with padding and L2 regularization
    keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-4)),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-4)),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Dropout(0.2),

    keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-4)),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-4)),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Dropout(0.3),
    
    # Flatten and Dense layers
    keras.layers.Flatten(),
    keras.layers.Dense(512, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(100, activation='softmax')
])

deeper_cnn.compile(optimizer='adam',
                     loss='categorical_crossentropy',
                     metrics=['accuracy'])
deeper_cnn.summary()
# Out:
# Model: "sequential_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_14 (Sequential)      │ (None, 32, 32, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 32, 32, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_17 (MaxPooling2D) │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_21 (Conv2D)              │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_22 (Conv2D)              │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_18 (MaxPooling2D) │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_15 (Flatten)            │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_43 (Dense)                │ (None, 512)            │     2,097,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_44 (Dense)                │ (None, 100)            │        51,300 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,216,772 (8.46 MB)
#  Trainable params: 2,215,364 (8.45 MB)
#  Non-trainable params: 1,408 (5.50 KB)

# %%
deeper_cnn_history = deeper_cnn.fit(
    train_images_gray,
    train_labels_one_hot,
    epochs=100,
    batch_size=50,
    validation_data=(test_images_gray, test_labels_one_hot),
)
# Out:
# Epoch 1/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 56s 53ms/step - accuracy: 0.0882 - loss: 4.3406 - val_accuracy: 0.1727 - val_loss: 3.6421
# Epoch 2/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 49s 49ms/step - accuracy: 0.1763 - loss: 3.5774 - val_accuracy: 0.2391 - val_loss: 3.2113
# Epoch 3/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 63s 63ms/step - accuracy: 0.2193 - loss: 3.3052 - val_accuracy: 0.2371 - val_loss: 3.3527
# Epoch 4/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 62s 62ms/step - accuracy: 0.2449 - loss: 3.1714 - val_accuracy: 0.2825 - val_loss: 3.0286
# Epoch 5/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 51s 51ms/step - accuracy: 0.2699 - loss: 3.0491 - val_accuracy: 0.2953 - val_loss: 2.9349
# Epoch 6/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 50s 50ms/step - accuracy: 0.2842 - loss: 2.9692 - val_accuracy: 0.2946 - val_loss: 3.0084
# Epoch 7/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 59s 59ms/step - accuracy: 0.2963 - loss: 2.8932 - val_accuracy: 0.3233 - val_loss: 2.7850
# Epoch 8/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 65s 65ms/step - accuracy: 0.3123 - loss: 2.8324 - val_accuracy: 0.3498 - val_loss: 2.7093
# Epoch 9/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 55s 55ms/step - accuracy: 0.3167 - loss: 2.7925 - val_accuracy: 0.3200 - val_loss: 2.8441
# Epoch 10/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 54s 53ms/step - accuracy: 0.3313 - loss: 2.7424 - val_accuracy: 0.3606 - val_loss: 2.6520
# Epoch 11/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 55s 55ms/step - accuracy: 0.3386 - loss: 2.7000 - val_accuracy: 0.3734 - val_loss: 2.5700
# Epoch 12/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 49s 49ms/step - accuracy: 0.3465 - loss: 2.6599 - val_accuracy: 0.3707 - val_loss: 2.6269
# Epoch 13/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 48s 48ms/step - accuracy: 0.3536 - loss: 2.6265 - val_accuracy: 0.4058 - val_loss: 2.4207
# Epoch 14/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 49s 49ms/step - accuracy: 0.3594 - loss: 2.5979 - val_accuracy: 0.3740 - val_loss: 2.5587
# Epoch 15/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 49s 49ms/step - accuracy: 0.3637 - loss: 2.5725 - val_accuracy: 0.4226 - val_loss: 2.3399
# Epoch 16/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 48s 48ms/step - accuracy: 0.3696 - loss: 2.5566 - val_accuracy: 0.4039 - val_loss: 2.3978
# Epoch 17/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 51s 51ms/step - accuracy: 0.3782 - loss: 2.5214 - val_accuracy: 0.3892 - val_loss: 2.5251
# Epoch 18/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 63s 63ms/step - accuracy: 0
100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 68s 68ms/step - accuracy: 0.4654 - loss: 2.1264 - val_accuracy: 0.4783 - val_loss: 2.1027
# Epoch 75/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 69s 69ms/step - accuracy: 0.4667 - loss: 2.1083 - val_accuracy: 0.4848 - val_loss: 2.0789
# Epoch 76/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 69s 68ms/step - accuracy: 0.4687 - loss: 2.1023 - val_accuracy: 0.4855 - val_loss: 2.0684
# Epoch 77/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 68s 68ms/step - accuracy: 0.4701 - loss: 2.0982 - val_accuracy: 0.4974 - val_loss: 2.0356
# Epoch 78/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 69s 69ms/step - accuracy: 0.4713 - loss: 2.0992 - val_accuracy: 0.4810 - val_loss: 2.1077
# Epoch 79/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 69s 69ms/step - accuracy: 0.4696 - loss: 2.1011 - val_accuracy: 0.4916 - val_loss: 2.0609
# Epoch 80/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 69s 69ms/step - accuracy: 0.4713 - loss: 2.1049 - val_accuracy: 0.4687 - val_loss: 2.1588
# Epoch 81/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 69s 69ms/step - accuracy: 0.4720 - loss: 2.0967 - val_accuracy: 0.4761 - val_loss: 2.1364
# Epoch 82/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 69s 69ms/step - accuracy: 0.4734 - loss: 2.0948 - val_accuracy: 0.4792 - val_loss: 2.0834
# Epoch 83/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 69s 69ms/step - accuracy: 0.4703 - loss: 2.0966 - val_accuracy: 0.4882 - val_loss: 2.0486
# Epoch 84/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 69s 69ms/step - accuracy: 0.4754 - loss: 2.0809 - val_accuracy: 0.4739 - val_loss: 2.1183
# Epoch 85/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 69s 69ms/step - accuracy: 0.4744 - loss: 2.0889 - val_accuracy: 0.4680 - val_loss: 2.1596
# Epoch 86/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 59s 59ms/step - accuracy: 0.4744 - loss: 2.0816 - val_accuracy: 0.4808 - val_loss: 2.0758
# Epoch 87/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 63s 63ms/step - accuracy: 0.4764 - loss: 2.0815 - val_accuracy: 0.4643 - val_loss: 2.1643
# Epoch 88/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 53s 53ms/step - accuracy: 0.4771 - loss: 2.0792 - val_accuracy: 0.4831 - val_loss: 2.0877
# Epoch 89/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 57s 57ms/step - accuracy: 0.4740 - loss: 2.0800 - val_accuracy: 0.4793 - val_loss: 2.1089
# Epoch 90/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 66s 66ms/step - accuracy: 0.4783 - loss: 2.0667 - val_accuracy: 0.4836 - val_loss: 2.0867
# Epoch 91/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 61s 61ms/step - accuracy: 0.4769 - loss: 2.0798 - val_accuracy: 0.4937 - val_loss: 2.0507
# Epoch 92/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 59s 59ms/step - accuracy: 0.4769 - loss: 2.0716 - val_accuracy: 0.4863 - val_loss: 2.0669
# Epoch 93/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 66s 66ms/step - accuracy: 0.4774 - loss: 2.0663 - val_accuracy: 0.4799 - val_loss: 2.1099
# Epoch 94/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 76s 76ms/step - accuracy: 0.4776 - loss: 2.0695 - val_accuracy: 0.4687 - val_loss: 2.1674
# Epoch 95/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 65s 65ms/step - accuracy: 0.4783 - loss: 2.0625 - val_accuracy: 0.4842 - val_loss: 2.1020
# Epoch 96/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 63s 63ms/step - accuracy: 0.4810 - loss: 2.0572 - val_accuracy: 0.4673 - val_loss: 2.1915
# Epoch 97/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 64s 64ms/step - accuracy: 0.4793 - loss: 2.0630 - val_accuracy: 0.4925 - val_loss: 2.0483
# Epoch 98/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 66s 66ms/step - accuracy: 0.4797 - loss: 2.0602 - val_accuracy: 0.4925 - val_loss: 2.0180
# Epoch 99/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 67s 67ms/step - accuracy: 0.4795 - loss: 2.0519 - val_accuracy: 0.4847 - val_loss: 2.0885
# Epoch 100/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 70s 69ms/step - accuracy: 0.4853 - loss: 2.0466 - val_accuracy: 0.4897 - val_loss: 2.0603

# %%
early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

model_checkpoint_deeper_cnn = keras.callbacks.ModelCheckpoint(
    filepath='best_deeper_cnn_model_cifar_weights.weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    mode='min',
    verbose=1
)

# %%
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6)

deeper_cnn_history = deeper_cnn.fit(
    train_images_gray,
    train_labels_one_hot,
    epochs=30,
    batch_size=50,
    validation_data=(test_images_gray, test_labels_one_hot),
    callbacks=[early_stopping, model_checkpoint_deeper_cnn, lr_scheduler] # Add scheduler
)
# Out:
# Epoch 1/30
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.4809 - loss: 2.0459
# Epoch 1: val_loss improved from None to 2.05569, saving model to best_deeper_cnn_model_cifar_weights.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 63s 63ms/step - accuracy: 0.4800 - loss: 2.0501 - val_accuracy: 0.4902 - val_loss: 2.0557 - learning_rate: 0.0010
# Epoch 2/30
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4859 - loss: 2.0299
# Epoch 2: val_loss did not improve from 2.05569
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 71s 71ms/step - accuracy: 0.4826 - loss: 2.0411 - val_accuracy: 0.4782 - val_loss: 2.1171 - learning_rate: 0.0010
# Epoch 3/30
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4847 - loss: 2.0313
# Epoch 3: val_loss improved from 2.05569 to 2.01801, saving model to best_deeper_cnn_model_cifar_weights.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 67s 67ms/step - accuracy: 0.4818 - loss: 2.0453 - val_accuracy: 0.4996 - val_loss: 2.0180 - learning_rate: 0.0010
# Epoch 4/30
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.4861 - loss: 2.0299
# Epoch 4: val_loss improved from 2.01801 to 2.00657, saving model to best_deeper_cnn_model_cifar_weights.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 76s 76ms/step - accuracy: 0.4844 - loss: 2.0404 - val_accuracy: 0.4995 - val_loss: 2.0066 - learning_rate: 0.0010
# Epoch 5/30
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.4859 - loss: 2.0302
# Epoch 5: val_loss did not improve from 2.00657
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 75s 75ms/step - accuracy: 0.4835 - loss: 2.0409 - val_accuracy: 0.4699 - val_loss: 2.1618 - learning_rate: 0.0010
# Epoch 6/30
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.4883 - loss: 2.0333
# Epoch 6: val_loss improved from 2.00657 to 1.95952, saving model to best_deeper_cnn_model_cifar_weights.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 84s 84ms/step - accuracy: 0.4856 - loss: 2.0400 - val_accuracy: 0.5080 - val_loss: 1.9595 - learning_rate: 0.0010
# Epoch 7/30
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.4880 - loss: 2.0339
# Epoch 7: val_loss did not improve from 1.95952
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 80s 80ms/step - accuracy: 0.4847 - loss: 2.0368 - val_accuracy: 0.5112 - val_loss: 1.9694 - learning_rate: 0.0010
# Epoch 8/30
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4853 - loss: 2.0292
# Epoch 8: val_loss did not improve from 1.95952
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 81s 81ms/step - accuracy: 0.4829 - loss: 2.0406 - val_accuracy: 0.4691 - val_loss: 2.1817 - learning_rate: 0.0010
# Epoch 9/30
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4855 - loss: 2.0243
# Epoch 9: val_loss did not improve from 1.95952
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 81s 81ms/step - accuracy: 0.4850 - loss: 2.0281 - val_accuracy: 0.4923 - val_loss: 2.0442 - learning_rate: 0.0010
# Epoch 10/30
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.4943 - loss: 1.9951
# Epoch 10: val_loss did not improve from 1.95952
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 76s 76ms/step - accuracy: 0.5005 - loss: 1.9656 - val_accuracy: 0.4982 - val_loss: 2.0128 - learning_rate: 2.0000e-04
# Epoch 11/30
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5062 - loss: 1.9495
# Epoch 11: val_loss did not improve from 1.95952
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 83s 83ms/step - accuracy: 0.5087 - loss: 1.9363 - val_accuracy: 0.5014 - val_loss: 2.0099 - learning_rate: 2.0000e-04

# %%
early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

model_checkpoint_ann = keras.callbacks.ModelCheckpoint(
    filepath='best_ann_model_cifar_weights.weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    mode='min',
    verbose=1
)

print("Training ANN model...")
ann_history = ann_model.fit(
    train_images_gray,
    train_labels_one_hot,
    epochs=30,
    batch_size=50,
    validation_data=(test_images_gray, test_labels_one_hot),
    callbacks=[early_stopping, model_checkpoint_ann]
)
print("ANN model training finished.")
# Out:
# Training ANN model...
# Epoch 1/30
#  997/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3743 - loss: 2.4950
# Epoch 1: val_loss improved from None to 5.85755, saving model to best_ann_model_cifar_weights.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.3701 - loss: 2.5211 - val_accuracy: 0.1375 - val_loss: 5.8576
# Epoch 2/30
#  993/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3775 - loss: 2.4719
# Epoch 2: val_loss did not improve from 5.85755
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.3693 - loss: 2.5173 - val_accuracy: 0.1361 - val_loss: 5.9557
# Epoch 3/30
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3821 - loss: 2.4668
# Epoch 3: val_loss improved from 5.85755 to 5.81163, saving model to best_ann_model_cifar_weights.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.3708 - loss: 2.5161 - val_accuracy: 0.1366 - val_loss: 5.8116
# Epoch 4/30
#  998/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3831 - loss: 2.4715
# Epoch 4: val_loss did not improve from 5.81163
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.3723 - loss: 2.5083 - val_accuracy: 0.1374 - val_loss: 5.8454
# Epoch 5/30
#  997/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3801 - loss: 2.4688
# Epoch 5: val_loss did not improve from 5.81163
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.3746 - loss: 2.5000 - val_accuracy: 0.1345 - val_loss: 5.9868
# Epoch 6/30
#  994/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3835 - loss: 2.4630
# Epoch 6: val_loss did not improve from 5.81163
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.3774 - loss: 2.4902 - val_accuracy: 0.1413 - val_loss: 5.9069
# Epoch 7/30
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3903 - loss: 2.4425
# Epoch 7: val_loss did not improve from 5.81163
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.3776 - loss: 2.4882 - val_accuracy: 0.1373 - val_loss: 5.9868
# Epoch 8/30
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3804 - loss: 2.4678
# Epoch 8: val_loss did not improve from 5.81163
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.3738 - loss: 2.4944 - val_accuracy: 0.1382 - val_loss: 5.9944
# ANN model training finished.

# %%
model_checkpoint_basic_cnn = keras.callbacks.ModelCheckpoint(
    filepath='best_basic_cnn_model_cifar_weights.weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    mode='min',
    verbose=1
)

print("Training Basic CNN model...")
basic_cnn_history = basic_cnn.fit(
    train_images_gray,
    train_labels_one_hot,
    epochs=30,
    batch_size=50,
    validation_data=(test_images_gray, test_labels_one_hot),
    callbacks=[early_stopping, model_checkpoint_basic_cnn]
)
print("Basic CNN model training finished.")
# Out:
# Training Basic CNN model...
# Epoch 1/30
#  998/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9784 - loss: 0.0854
# Epoch 1: val_loss improved from None to 17.76724, saving model to best_basic_cnn_model_cifar_weights.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - accuracy: 0.9762 - loss: 0.0961 - val_accuracy: 0.2665 - val_loss: 17.7672
# Epoch 2/30
#  999/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9780 - loss: 0.0822
# Epoch 2: val_loss improved from 17.76724 to 17.48141, saving model to best_basic_cnn_model_cifar_weights.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - accuracy: 0.9755 - loss: 0.0951 - val_accuracy: 0.2644 - val_loss: 17.4814
# Epoch 3/30
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9784 - loss: 0.0791
# Epoch 3: val_loss did not improve from 17.48141
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 19s 18ms/step - accuracy: 0.9757 - loss: 0.0930 - val_accuracy: 0.2656 - val_loss: 17.6492
# Epoch 4/30
#  998/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9775 - loss: 0.0816
# Epoch 4: val_loss did not improve from 17.48141
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - accuracy: 0.9746 - loss: 0.1003 - val_accuracy: 0.2711 - val_loss: 17.5585
# Epoch 5/30
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9779 - loss: 0.0843
# Epoch 5: val_loss did not improve from 17.48141
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 17s 17ms/step - accuracy: 0.9767 - loss: 0.0914 - val_accuracy: 0.2686 - val_loss: 17.6205
# Basic CNN model training finished.

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report

ann_model.load_weights('best_ann_model_cifar_weights.weights.h5')
basic_cnn.load_weights('best_basic_cnn_model_cifar_weights.weights.h5')
deeper_cnn.load_weights('best_deeper_cnn_model_cifar_weights.weights.h5')

loss_ann, accuracy_ann = ann_model.evaluate(test_images_gray, test_labels_one_hot, verbose=0)
loss_basic_cnn, accuracy_basic_cnn = basic_cnn.evaluate(test_images_gray, test_labels_one_hot, verbose=0)
loss_deeper_cnn, accuracy_deeper_cnn = deeper_cnn.evaluate(test_images_gray, test_labels_one_hot, verbose=0)


import matplotlib.pyplot as plt
import numpy as np

# Data
models = ['ANN', 'Basic CNN', 'Deeper CNN']
losses = [loss_ann, loss_basic_cnn, loss_deeper_cnn]
accuracies = [accuracy_ann, accuracy_basic_cnn, accuracy_deeper_cnn]

# Dark mode style
plt.style.use("dark_background")

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Loss plot
axes[0].bar(models, losses, color='#FF6F61', edgecolor='white')
axes[0].set_title('Model Test Loss', fontsize=14, fontweight='bold')
axes[0].set_ylabel('Loss', fontsize=12)
axes[0].grid(True, linestyle='--', alpha=0.4)

# Accuracy plot
axes[1].bar(models, accuracies, color='#6BCB77', edgecolor='white')
axes[1].set_title('Model Test Accuracy', fontsize=14, fontweight='bold')
axes[1].set_ylabel('Accuracy', fontsize=12)
axes[1].grid(True, linestyle='--', alpha=0.4)

# Overall title
plt.suptitle("Model Performance Comparison", fontsize=16, fontweight='bold')

plt.tight_layout()
plt.show()

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

models = {
    "ANN": ("cyan", ann_history),
    "Basic CNN": ("magenta", basic_cnn_history),
    "Deeper CNN": ("yellow", deeper_cnn_history)
}

performance_data = {
    'Model': ['ANN', 'Basic CNN', 'Deeper CNN'],
    'Test Loss': [loss_ann, loss_basic_cnn, loss_deeper_cnn],
    'Test Accuracy': [accuracy_ann, accuracy_basic_cnn, accuracy_deeper_cnn]
}

performance_df = pd.DataFrame(performance_data)

fig = make_subplots(rows=1, cols=2, subplot_titles=('Accuracy', 'Loss'))

for name, (color, history) in models.items():
    # Accuracy
    fig.add_trace(go.Scatter(y=history.history['accuracy'], mode='lines',
                             name=name, line=dict(color=color, dash='solid')), row=1, col=1)
    fig.add_trace(go.Scatter(y=history.history['val_accuracy'], mode='lines',
                             name=name, line=dict(color=color, dash='dot'), showlegend=False), row=1, col=1)

    # Loss
    fig.add_trace(go.Scatter(y=history.history['loss'], mode='lines',
                             name=name, line=dict(color=color, dash='solid')), row=1, col=2)
    fig.add_trace(go.Scatter(y=history.history['val_loss'], mode='lines',
                             name=name, line=dict(color=color, dash='dot'), showlegend=False), row=1, col=2)

fig.update_layout(
    title_text="Model Comparison: Accuracy & Loss (Train=Solid, Val=Dot)",
    height=500,
    width=1200,
    template="plotly_dark"
)

fig.show()
